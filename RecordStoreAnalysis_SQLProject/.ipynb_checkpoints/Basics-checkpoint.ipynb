# %% [markdown]
# ## SQL Business Analysis Project
# Soham Sen | Jan 23, 2018

# %% [markdown]
# ### A. Import the Packages

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plot
import numpy as np
from datetime import date

# %matplotlib inline

# %% [markdown]
# ### B. Load Data and Set up Functions

# %%
def run_query(q):
    with sqlite3.connect('chinook.db') as conn:
        return pd.read_sql(q, conn)

# %%
def run_command(c):
    with sqlite3.connect('chinook.db') as conn:
        conn.isolation_level = None
        conn.execute(c)

# %%
def show_tables():
    qry = "SELECT name, type FROM sqlite_master WHERE type IN ('table', 'view');"
    return run_query(qry)

# %%
show_tables()
# Out:
#               name   type
# 0            album  table
# 1           artist  table
# 2         customer  table
# 3         employee  table
# 4            genre  table
# 5          invoice  table
# 6     invoice_line  table
# 7       media_type  table
# 8         playlist  table
# 9   playlist_track  table
# 10           track  table

# %% [markdown]
# ### 1. Which Artists to Sign based on Genre Popularity

# %%
q = '''
SELECT 
    g.name genre,
    SUM(il.quantity) tracks_sold,
    100*SUM(il.quantity)/(SELECT SUM(quantity) FROM invoice_line) AS pct
FROM genre g 
INNER JOIN track t ON t.genre_id = g.genre_id
INNER JOIN invoice_line il ON il.track_id = t.track_id
INNER JOIN invoice i ON i.invoice_id = il.invoice_id
WHERE i.billing_country = "USA"
GROUP BY 1
ORDER BY 2 DESC
'''

tracksByGenre = run_query(q)

tracksByGenre
# Out:
#                  genre  tracks_sold  pct
# 0                 Rock          561   11
# 1   Alternative & Punk          130    2
# 2                Metal          124    2
# 3             R&B/Soul           53    1
# 4                Blues           36    0
# 5          Alternative           35    0
# 6                Latin           22    0
# 7                  Pop           22    0
# 8          Hip Hop/Rap           20    0
# 9                 Jazz           14    0
# 10      Easy Listening           13    0
# 11              Reggae            6    0
# 12   Electronica/Dance            5    0
# 13           Classical            4    0
# 14         Heavy Metal            3    0
# 15          Soundtrack            2    0
# 16            TV Shows            1    0

# %%
tracksByGenre.plot(kind='bar', x='genre', y='pct')

# %% [markdown]
# The analysis suggest that rock, aternative, metal and R&B are by far the highest selling genres. So the artists don't seem like a great fit for Chinook. The Punk artist Red Tone seems like the best of the lot. Then the Blues artist. Po and Hip-hop after that.

# %% [markdown]
# ### 2. Analyzing Employee Sales Peformance

# %%
q2 = '''
WITH 
    customer_sales AS 
        (
            SELECT c.*, SUM(i.total) total_sales
            FROM customer c
            INNER JOIN invoice i ON i.customer_id = c.customer_id
            GROUP BY c.customer_id
            ORDER BY 2
               
        ),
    rep_sales AS
        (
            SELECT 
                support_rep_id support_rep,
                SUM(total_sales) agg_sales
            FROM customer_sales
            GROUP BY 1
            ORDER BY 2 DESC
        )

SELECT 
    rp.*, 
    e.first_name || ' ' || e.last_name fullname,
    e.title title,
    e.reports_to supervisor,
    e.country,
    e.city,
    e.hire_date
FROM rep_sales rp
INNER JOIN employee e ON e.employee_id = rp.support_rep
'''

repPerf = run_query(q2)
repPerf['hire_date'] = pd.to_datetime(repPerf.hire_date)
repPerf['experience'] = ((date.today() - repPerf.hire_date)/np.timedelta64(1, 'D')).astype(int)
repPerf
# Out:
#    support_rep  agg_sales       fullname                title  supervisor  \
# 0            3    1731.51   Jane Peacock  Sales Support Agent           2
# 1            4    1584.00  Margaret Park  Sales Support Agent           2
# 2            5    1393.92  Steve Johnson  Sales Support Agent           2
#
#   country     city  hire_date  experience
# 0  Canada  Calgary 2017-04-01         298
# 1  Canada  Calgary 2017-05-03         266
# 2  Canada  Calgary 2017-10-17          99

# %%
repPerf.plot.bar(x='fullname', y='agg_sales').set_title('Sales by Rep')

# %%
repPerf.plot.scatter(x='experience', y='agg_sales')

# %% [markdown]
# Doesn't look like there is that much difference between the three agents. Whatever variation there is is not due to supervisor or location which are same across the three. There does seem to be some correlation betwen experience and performance.

# %% [markdown]
# ### Analyzing Sales by Country

# %%
q3 = '''
WITH 
    order_details AS
        (
            SELECT c.customer_id, i.invoice_id, c.country, i.total
            FROM customer c
            INNER JOIN invoice i ON i.customer_id = c.customer_id
        )

SELECT 
    country,
    COUNT(DISTINCT customer_id) customer_count,
    SUM(total) total_sales,
    SUM(total)/COUNT(DISTINCT customer_id) avg_customer_sale, 
    SUM(total)/COUNT(invoice_id) avg_order_value
FROM order_details
GROUP BY country
ORDER BY 2 DESC
'''

run_query(q3)
# Out:
#            country  customer_count  total_sales  avg_customer_sale  \
# 0              USA              13      1040.49          80.037692
# 1           Canada               8       535.59          66.948750
# 2           Brazil               5       427.68          85.536000
# 3           France               5       389.07          77.814000
# 4          Germany               4       334.62          83.655000
# 5   United Kingdom               3       245.52          81.840000
# 6   Czech Republic               2       273.24         136.620000
# 7            India               2       183.15          91.575000
# 8         Portugal               2       185.13          92.565000
# 9        Argentina               1        39.60          39.600000
# 10       Australia               1        81.18          81.180000
# 11         Austria               1        69.30          69.300000
# 12         Belgium               1        60.39          60.390000
# 13           Chile               1        97.02          97.020000
# 14         Denmark               1        37.62          37.620000
# 15         Finland               1        79.20          79.200000
# 16         Hungary               1        78.21          78.210000
# 17         Ireland               1       114.84         114.840000
# 18           Italy               1        50.49          50.490000
# 19     Netherlands               1        65.34          65.340000
# 20          Norway               1        72.27          72.270000
# 21          Poland               1        76.23          76.230000
# 22           Spain               1        98.01          98.010000
# 23          Sweden               1        75.24          75.240000
#
#     avg_order_value
# 0          7.942672
# 1          7.047237
# 2          7.011148
# 3          7.781400
# 4          8.161463
# 5          8.768571
# 6          9.108000
# 7          8.721429
# 8          6.383793
# 9          7.920000
# 10         8.118000
# 11         7.700000
# 12         8.627143
# 13         7.463077
# 14         3.762000
# 15         7.200000
# 16         7.821000
# 17         8.833846
# 18         5.610000
# 19         6.534000
# 20         8.030000
# 21         7.623000
# 22         8.910000
# 23         7.524000

# %%
q3 = '''
WITH 
    order_details AS
        (
            SELECT c.customer_id, i.invoice_id, c.country country1, i.total
            FROM customer c
            INNER JOIN invoice i ON i.customer_id = c.customer_id
        ),
    country_orders AS
        (
            SELECT 
                country1,
                COUNT(DISTINCT customer_id) customer_count,
                SUM(total) total_sales,
                COUNT(invoice_id) total_orders
            FROM order_details
            GROUP BY country1
            ORDER BY 2 DESC

        ),
    country_orders_adj AS
        (
            SELECT
                *,
                CASE
                    WHEN customer_count > 1 THEN country1
                    ELSE "Other"
                END AS country
            FROM country_orders

        ),
        
    country_orders_agg AS
        (
            SELECT
                country,
                total_sales,
                total_sales/customer_count avg_val_customer,
                total_sales/total_orders avg_order_val
            FROM country_orders_adj
            GROUP BY 1
            ORDER BY 2

        )

SELECT * 
FROM 
    (
       SELECT co.*,
       CASE
           WHEN co.country = "Other" THEN 1
           ELSE 0
        END AS sort
        FROM country_orders_agg co
    )
ORDER BY total_sales DESC, sort ASC
'''

run_query(q3)
