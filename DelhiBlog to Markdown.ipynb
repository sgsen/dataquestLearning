# %% [markdown]
# ## Dusting off an Old Blog
#
# Sometime ago, about ten years, on my first trip to India I had kept a blog over the first several months. After that, I suspect I got far too busy to keep it up. I had forgotten about it until I started writing agaain a few weeks ago. And I thought it might be fun to try and find it. As it turned out, all I had of it was a sql dump from the wordpress database I had back then. Extracting and formatting it manually would be a pain, so I thought I'd use this as an opportunity to apply some of the recent learning using sql, some basic formatting functions, markdown, etc to do the work for me. Notes on that below. This took the better part of a Sunday afternoon. A lot of that actually just getting mySQL to work, but still I was reminded that knowing how to do something and having the fluency that comes from having mastered it are two totally different things.

# %% [markdown]
# ### A. Setup

# %%
import pymysql
import pandas as pd
import html2text
import string

# %matplotlib inline

# %%
conn = pymysql.connect(host='localhost',
                             user='root',
                             password='gremlins',
                             db='delhiblog')

def run_query(q):
    return pd.read_sql(q, conn)

# %%
q = 'select id, post_date, post_title, post_content from wp_posts;'

df = run_query(q)

df
# Out:
#     id           post_date                                         post_title  \
# 0    1 2006-12-24 22:10:49         Washington to Delhi: Preparations Underway
# 1    2 2006-12-24 22:10:49                                              About
# 2    3 2007-01-10 01:01:13                              DC to London to Delhi
# 3    4 2007-01-25 12:28:55                                   A Place to Start
# 4    5 2007-01-30 09:06:36                                  Changing Times...
# 5    6 2007-01-30 09:54:15                     Ashoka in the New York Times!!
# 6    7 2007-02-05 15:11:36         Super Bowl XLI over Coffee in Chanakyapuri
# 7    8 2007-02-06 12:16:02                       Encounter of a Poetic Nature
# 8    9 2007-02-09 15:49:34                                   CR Park in Delhi
# 9   10 2007-02-09 16:12:37                                Kali Mandir CR Park
# 10  11 2007-02-09 16:14:21                       Location, Location, Location
# 11  12 2007-02-12 23:06:23                                          "My Cave"
# 12  15 2007-02-27 23:24:22  Cows and Camels and Elephants Oh My! (The Street)
# 13  14 2007-02-19 18:52:16                                Domestic Assistants
# 14  16 2007-02-28 20:55:35         Delhi Lessons Part I: The Kitna Hoga Tango
# 15  17 2007-03-12 22:24:29                                  The Golden Temple
# 16  18 2007-03-14 18:19:36  Life in Delhi Lesson II: Thou shalt have no pe...
# 17  19 2007-03-29 22:56:39                                    Bengali Wedding
# 18  20 2007-04-15 21:57:57                                   The Wagah Border
# 19  21 2007-04-22 21:29:53  Life in Delhi Lesson III: Thou Must Be Aggress...
# 20  22                 NaT                                            Travels
#
#                                          post_content
# 0   <div style="text-align: center"><img alt="The ...
# 1   This is an example of a WordPress page, you co...
# 2   I don't have much time, but I wanted to write ...
# 3   Ive been here on the ground for just over two...
# 4   I finished the last post talking about what ha...
# 5   I remember a lot of you wondering what work I ...
# 6   I met up with some friends after work on Frida...
# 7   I had a chance to see a poetry reading by <a t...
# 8
# 9
# 10  So I, apparently,  don't know the first thing ...
# 11  I must admit that I had little idea about what...
# 12  <p align="center"><img title="Yes an elephant!...
# 13  <div style="text-align: center"><img title="My...
# 14  I've now written in some details about much of...
# 15  I keep thinking that I will find time to write...
# 16  <div align="center"><img alt="People, people e...
# 17  <p align="center" style="margin-bottom: 0.2in;...
# 18  <div align="center"><img title="Nationalistic ...
# 19  <p align="center"><img alt="Everybody needs to...
# 20  I've managed to squeeze in a fair amount of tr...

# %% [markdown]
# ### B. Plan of Approach
#
# This is what I'm thinking:
#
# * loop through the list of posts
# * copy the content into a dictionary - this is probably not necessary on second thought; can just leave in dataframe; don't think there is additional value.
# * add the yaml content at the top which looks like the below; basically you only care about title and date
#     * the title will need to be condensed a bit
#     * will need date
# * save the files title in a particular way: date-title.md in some folder
#
#
# ```
# ---
# layout: post
# title: "Mother is Supreme"
# date: 2003-09-03
# categories: [college]
# ---
#
# ```

# %% [markdown]
# ### C. Preliminaries: Testing the pieces

# %% [markdown]
# #### 1. What does the post content look like?

# %%
q = 'select post_content from wp_posts where ID = 1;'

result = run_query(q)

result.post_content[0]
# Out:
# '<div style="text-align: center"><img alt="The White House" title="The White House" src="http://www.barton.edu/school-dept/history&ss/White%20House.jpeg" /></div>\r\n<div style="text-align: center"><strong>From the White House...</strong></div>\r\nLeaving the country for six months is -- as it turns out -- not that easy to do; its something of a logistical nightmare. Where will your mail go? How will I get money over there? What should I do with my car insuance? These are a few of the never ending number of things that I\'m trying to figure out and handle. And of course, getting business done during Christmas break is almost futile because like me, nobody is at work. Anyway, suffice it to say that I have 14 days left before I leave for Delhi, and there is much to do.\r\n\r\nAll of this stuff to do before Delhi has left me little time to think of how it will be to actually be in Delhi. I\'ve seen photos of Delhi so I think I\'m somewhat prepared for what it will look like at lease. And I\'m almost done reading this book called a City of Djinns by William Dalrymple which is about this British author\'s year in Delhi. The book is half travel log and half historical perspective. I find that I have some sense of the complicated and variegated history of Delhi having read most of the book. Yet, Delhi like the rest of the country, has changed a great deal since 1993 when this book was written, and this makes it hard to get an idea of what I might there culturally.\r\n\r\nThere is also the personal aspect in all of this for me in that makes this travel abroad different than other trips I\'ve taken before. This time, I\'m not headed to Guatemala or Italy, but to the land of my birth, the land of my ancestors. And, I come as a stranger. A foreigner with an US passport. In Italy I this was expected and fine. But returning to India is ambiguous. Should I really think of myself as leaving home (Washington) or returning home (India)? I suppose one of the motivations of this adventure is to find out.\r\n<div style="text-align: center"><img width="439" height="329" alt="The Red Fort" title="The Red Fort" src="http://www.cs.washington.edu/homes/cmprince/images/India_2004/Delhi_Red_Fort01-Small.jpg" /></div>\r\n<div style="text-align: center"><strong>...to the Red Fort</strong></div>'

# %% [markdown]
# #### 2. The meta content

# %%
testyaml = '''
---
layout: post\r
title: "Mother is Supreme"\r
date: 2003-09-03\r
categories: [college]\r
---\n
'''

print(testyaml)
# Out:
# ---
# layout: post
# title: "Mother is Supreme"
# date: 2003-09-03
# categories: [college]
# ---

# %% [markdown]
# #### 3. Converting to Markdown

# %%
print(html2text.html2text("<p>Hello, <a href='http://earth.google.com/'>world</a>!"))
# Out:
# Hello, [world](http://earth.google.com/)!

# %%
print(st)
# Out:
# ---
# layout: post
# title: "Mother is Supreme"
# date: 2003-09-03
# categories: [college]
# ---
#
# ![The White House](http://www.barton.edu/school-
# dept/history&ss/White%20House.jpeg)
#
# **From the White House...**
#
# Leaving the country for six months is -- as it turns out -- not that easy to
# do; its something of a logistical nightmare. Where will your mail go? How will
# I get money over there? What should I do with my car insuance? These are a few
# of the never ending number of things that I'm trying to figure out and handle.
# And of course, getting business done during Christmas break is almost futile
# because like me, nobody is at work. Anyway, suffice it to say that I have 14
# days left before I leave for Delhi, and there is much to do. All of this stuff
# to do before Delhi has left me little time to think of how it will be to
# actually be in Delhi. I've seen photos of Delhi so I think I'm somewhat
# prepared for what it will look like at lease. And I'm almost done reading this
# book called a City of Djinns by William Dalrymple which is about this British
# author's year in Delhi. The book is half travel log and half historical
# perspective. I find that I have some sense of the complicated and variegated
# history of Delhi having read most of the book. Yet, Delhi like the rest of the
# country, has changed a great deal since 1993 when this book was written, and
# this makes it hard to get an idea of what I might there culturally. There is
# also the personal aspect in all of this for me in that makes this travel
# abroad different than other trips I've taken before. This time, I'm not headed
# to Guatemala or Italy, but to the land of my birth, the land of my ancestors.
# And, I come as a stranger. A foreigner with an US passport. In Italy I this
# was expected and fine. But returning to India is ambiguous. Should I really
# think of myself as leaving home (Washington) or returning home (India)? I
# suppose one of the motivations of this adventure is to find out.
#
# ![The Red Fort](http://www.cs.washington.edu/homes/cmprince/images/India_2004/
# Delhi_Red_Fort01-Small.jpg)
#
# **...to the Red Fort**

# %% [markdown]
# #### 4. Writing String to a File

# %%
f = open("test.md","w") #opens file with name of "test.txt"
st = testyaml+html2text.html2text(result.post_content[0])
f.write(st)

f.close()

# %% [markdown]
# ### Write the Functions

# %% [markdown]
# #### Extract the Date
# There is date time and I just want the date formatted as a string

# %%
df['justDate'] = df['post_date'].dt.date

# %%
df.sample(5)
# Out:
#     id           post_date                                  post_title  \
# 11  12 2007-02-12 23:06:23                                   "My Cave"
# 2    3 2007-01-10 01:01:13                       DC to London to Delhi
# 14  16 2007-02-28 20:55:35  Delhi Lessons Part I: The Kitna Hoga Tango
# 6    7 2007-02-05 15:11:36  Super Bowl XLI over Coffee in Chanakyapuri
# 7    8 2007-02-06 12:16:02                Encounter of a Poetic Nature
#
#                                          post_content    justDate
# 11  I must admit that I had little idea about what...  2007-02-12
# 2   I don't have much time, but I wanted to write ...  2007-01-10
# 14  I've now written in some details about much of...  2007-02-28
# 6   I met up with some friends after work on Frida...  2007-02-05
# 7   I had a chance to see a poetry reading by <a t...  2007-02-06

# %% [markdown]
# #### Extract the Short Title
# The titles are too long in some cases; need a shorter version

# %%
def getFileName(row):
    x = row.post_title
    d = row.justDate
    
    maxt = 25;
    exclude = set(string.punctuation)
    x = ''.join(ch for ch in x if ch not in exclude)
    if len(x) < maxt:
        x = x.replace(" ","")
    else:
        x = ''.join(x[:maxt+1].split(' ')[0:-1])
    return (str(d)+'-'+x+'.md')

# %%
df['fileName'] = df.apply(getFileName, axis = 1)

# %%
df.sample(5)
# Out:
#     id           post_date                                  post_title  \
# 7    8 2007-02-06 12:16:02                Encounter of a Poetic Nature
# 5    6 2007-01-30 09:54:15              Ashoka in the New York Times!!
# 14  16 2007-02-28 20:55:35  Delhi Lessons Part I: The Kitna Hoga Tango
# 2    3 2007-01-10 01:01:13                       DC to London to Delhi
# 1    2 2006-12-24 22:10:49                                       About
#
#                                          post_content    justDate  \
# 7   I had a chance to see a poetry reading by <a t...  2007-02-06
# 5   I remember a lot of you wondering what work I ...  2007-01-30
# 14  I've now written in some details about much of...  2007-02-28
# 2   I don't have much time, but I wanted to write ...  2007-01-10
# 1   This is an example of a WordPress page, you co...  2006-12-24
#
#                               fileName
# 7     2007-02-06-EncounterofaPoetic.md
# 5     2007-01-30-AshokaintheNewYork.md
# 14  2007-02-28-DelhiLessonsPartIThe.md
# 2      2007-01-10-DCtoLondontoDelhi.md
# 1                  2006-12-24-About.md

# %%
import string
s = "string. With. Punctuation?" # Sample string 
exclude = set(string.punctuation)
s = ''.join(ch for ch in s if ch not in exclude)
print(s)
# Out:
# string With Punctuation

# %% [markdown]
# #### Construct YAML

# %%
def buildYAML(row):
    d = str(row.justDate)
    t = row.post_title
    
    s = '''
    ---
    layout: post\r
    title: "{}"\r
    date: {}\r
    categories: [delhiblog2007]\r
    ---\n
    '''.format(t,d)
    return s

# %%
df['yaml'] = df.apply(buildYAML, axis = 1)

# %%
df.sample(5)
# Out:
#     id           post_date                                         post_title  \
# 0    1 2006-12-24 22:10:49         Washington to Delhi: Preparations Underway
# 3    4 2007-01-25 12:28:55                                   A Place to Start
# 11  12 2007-02-12 23:06:23                                          "My Cave"
# 19  21 2007-04-22 21:29:53  Life in Delhi Lesson III: Thou Must Be Aggress...
# 9   10 2007-02-09 16:12:37                                Kali Mandir CR Park
#
#                                          post_content    justDate  \
# 0   <div style="text-align: center"><img alt="The ...  2006-12-24
# 3   Ive been here on the ground for just over two...  2007-01-25
# 11  I must admit that I had little idea about what...  2007-02-12
# 19  <p align="center"><img alt="Everybody needs to...  2007-04-22
# 9                                                      2007-02-09
#
#                               fileName  \
# 0      2006-12-24-WashingtontoDelhi.md
# 3          2007-01-25-APlacetoStart.md
# 11                2007-02-12-MyCave.md
# 19  2007-04-22-LifeinDelhiLessonIII.md
# 9       2007-02-09-KaliMandirCRPark.md
#
#                                                  yaml
# 0   \n    ---\n    layout: post\r\n    title: "Was...
# 3   \n    ---\n    layout: post\r\n    title: "A P...
# 11  \n    ---\n    layout: post\r\n    title: ""My...
# 19  \n    ---\n    layout: post\r\n    title: "Lif...
# 9   \n    ---\n    layout: post\r\n    title: "Kal...

# %% [markdown]
# #### Loop through dataframe, generate markdown, and write to file

# %%
def getMdContent(row):
    yaml = row.yaml
    content = row.post_content
        
    mdcontent = html2text.html2text(content)
    mdcontent = yaml + mdcontent
    
    return mdcontent

# %%
df['md_content'] = df.apply(getMdContent, axis = 1)

df.sample(5)
# Out:
#     id           post_date                                         post_title  \
# 12  15 2007-02-27 23:24:22  Cows and Camels and Elephants Oh My! (The Street)
# 1    2 2006-12-24 22:10:49                                              About
# 8    9 2007-02-09 15:49:34                                   CR Park in Delhi
# 11  12 2007-02-12 23:06:23                                          "My Cave"
# 6    7 2007-02-05 15:11:36         Super Bowl XLI over Coffee in Chanakyapuri
#
#                                          post_content    justDate  \
# 12  <p align="center"><img title="Yes an elephant!...  2007-02-27
# 1   This is an example of a WordPress page, you co...  2006-12-24
# 8                                                      2007-02-09
# 11  I must admit that I had little idea about what...  2007-02-12
# 6   I met up with some friends after work on Frida...  2007-02-05
#
#                           fileName  \
# 12  2007-02-27-CowsandCamelsand.md
# 1              2006-12-24-About.md
# 8      2007-02-09-CRParkinDelhi.md
# 11            2007-02-12-MyCave.md
# 6   2007-02-05-SuperBowlXLIover.md
#
#                                                  yaml  \
# 12  \n    ---\n    layout: post\r\n    title: "Cow...
# 1   \n    ---\n    layout: post\r\n    title: "Abo...
# 8   \n    ---\n    layout: post\r\n    title: "CR ...
# 11  \n    ---\n    layout: post\r\n    title: ""My...
# 6   \n    ---\n    layout: post\r\n    title: "Sup...
#
#                                            md_content
# 12  \n    ---\n    layout: post\r\n    title: "Cow...
# 1   \n    ---\n    layout: post\r\n    title: "Abo...
# 8   \n    ---\n    layout: post\r\n    title: "CR ...
# 11  \n    ---\n    layout: post\r\n    title: ""My...
# 6   \n    ---\n    layout: post\r\n    title: "Sup...

# %%
def writeBlogs(row):
    filename = row.fileName
    content = row.md_content
    status = 'none'
    
    try:
        f = open(filename,"w") #opens file with name of "test.txt"
        f.write(content)
        f.close()
        status = 'success'
    except:
        status = 'fail'
        
    return status

# %%
df['writeStatus'] = df.apply(writeBlogs, axis=1)
df.sample(5)
# Out:
#     id           post_date                                  post_title  \
# 7    8 2007-02-06 12:16:02                Encounter of a Poetic Nature
# 20  22                 NaT                                     Travels
# 8    9 2007-02-09 15:49:34                            CR Park in Delhi
# 6    7 2007-02-05 15:11:36  Super Bowl XLI over Coffee in Chanakyapuri
# 11  12 2007-02-12 23:06:23                                   "My Cave"
#
#                                          post_content    justDate  \
# 7   I had a chance to see a poetry reading by <a t...  2007-02-06
# 20  I've managed to squeeze in a fair amount of tr...         NaN
# 8                                                      2007-02-09
# 6   I met up with some friends after work on Frida...  2007-02-05
# 11  I must admit that I had little idea about what...  2007-02-12
#
#                             fileName  \
# 7   2007-02-06-EncounterofaPoetic.md
# 20                    nan-Travels.md
# 8        2007-02-09-CRParkinDelhi.md
# 6     2007-02-05-SuperBowlXLIover.md
# 11              2007-02-12-MyCave.md
#
#                                                  yaml  \
# 7   \n    ---\n    layout: post\r\n    title: "Enc...
# 20  \n    ---\n    layout: post\r\n    title: "Tra...
# 8   \n    ---\n    layout: post\r\n    title: "CR ...
# 6   \n    ---\n    layout: post\r\n    title: "Sup...
# 11  \n    ---\n    layout: post\r\n    title: ""My...
#
#                                            md_content writeStatus
# 7   \n    ---\n    layout: post\r\n    title: "Enc...     success
# 20  \n    ---\n    layout: post\r\n    title: "Tra...     success
# 8   \n    ---\n    layout: post\r\n    title: "CR ...     success
# 6   \n    ---\n    layout: post\r\n    title: "Sup...     success
# 11  \n    ---\n    layout: post\r\n    title: ""My...     success
